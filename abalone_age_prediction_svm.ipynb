# %% [markdown]
# # Abalone Age Prediction

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from helper_functions import plot_pred

# %% [markdown]
# ## Data loading

# %%
file_path = './data/abalone.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df['Age'] = df['Rings'] + 1.5

df = df.drop(['Rings'], axis=1)

df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %% [markdown]
# ## Data exploration

# %% [markdown]
# ### Data Analysis

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight          Age
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831    11.433684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     2.500000
# 25%          0.093500      0.130000     9.500000
# 50%          0.171000      0.234000    10.500000
# 75%          0.253000      0.329000    12.500000
# max          0.760000      1.005000    30.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Age             4177 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 293.8+ KB

# %%
# Get the shape of the data
df.shape
# Out:
# (4177, 9)

# %%
# Get the column names
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Age'],
#       dtype='object')

# %%
# Count missing values
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Age               0
# dtype: int64

# %%
# Select duplicated rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Age]
# Index: []

# %% [markdown]
# Seems like there is no duplicated data

# %%
# Select categorical data, numerical data
categorical_data = df.select_dtypes(['object'])
numerical_data = df.select_dtypes(['float64', 'int64'])

categorical_data.head(), numerical_data.head()
# Out:
# (  Sex
#  0   M
#  1   M
#  2   F
#  3   M
#  4   I,
#     Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
#  0   0.455     0.365   0.095        0.5140          0.2245          0.1010
#  1   0.350     0.265   0.090        0.2255          0.0995          0.0485
#  2   0.530     0.420   0.135        0.6770          0.2565          0.1415
#  3   0.440     0.365   0.125        0.5160          0.2155          0.1140
#  4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#     Shell weight   Age
#  0         0.150  16.5
#  1         0.070   8.5
#  2         0.210  10.5
#  3         0.155  11.5
#  4         0.055   8.5  )

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    1528
# I    1342
# F    1307
# Name: count, dtype: int64

# %% [markdown]
# ### Data visualization

# %%
# Plot age
plt.figure(figsize=(12, 23))
for i, col in enumerate(numerical_data):
  plt.title(col, fontsize=12)
  ax = plt.subplot(5, 2, i+1)
  if col == 'Sex':
    df[col].value_counts().plot.bar()
  else:
    df[col].plot.hist()
plt.axis(False)
# Out:
# (np.float64(1.0999999999999999),
#  np.float64(31.9),
#  np.float64(0.0),
#  np.float64(1730.4))

# %%
plt.boxplot(df['Age'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13ee2b350>,
#   <matplotlib.lines.Line2D at 0x13ee5db50>],
#  'caps': [<matplotlib.lines.Line2D at 0x13ee5e450>,
#   <matplotlib.lines.Line2D at 0x13ee5edd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13ee5c8d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13ee5f710>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13ee5ff10>],
#  'means': []}

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Feature Correlation

# %%
pearson_corr = df.corr('pearson', numeric_only=True)
pearson_corr
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Age             0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight       Age
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Age                   0.503819      0.627574  1.000000

# %%
sns.heatmap(pearson_corr, cmap='PiYG', annot=True, vmax=1, vmin=-1)
# Out:
# <Axes: >

# %% [markdown]
# ### Remove outliers

# %%
def remove_outliers(df: pd.DataFrame):
  numerical_df = df.select_dtypes(include=np.number)
  Q1 = numerical_df.quantile(0.25)
  Q3 = numerical_df.quantile(0.75)
  IQR = Q3 - Q1
  
  outlier = ((numerical_df < (Q1 - 1.5 * IQR)) | (numerical_df > (Q3 + 1.5 * IQR))).any(axis=1)
  return df[~outlier]

df = remove_outliers(df)
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight   Age
# 0         0.150  16.5
# 1         0.070   8.5
# 2         0.210  10.5
# 3         0.155  11.5
# 4         0.055   8.5

# %%
plt.boxplot(df['Age'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13eff4550>,
#   <matplotlib.lines.Line2D at 0x13eff4e50>],
#  'caps': [<matplotlib.lines.Line2D at 0x13eff5690>,
#   <matplotlib.lines.Line2D at 0x13eff5fd0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13efe7ad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13eff6950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13eff7150>],
#  'means': []}

# %% [markdown]
# ### Data Encoding

# %%
df['Sex'].head()
# Out:
# 0    M
# 1    M
# 2    F
# 3    M
# 4    I
# Name: Sex, dtype: object

# %%
df['Sex'] = df['Sex'].replace({'M': 0, 'F': 1, 'I': 2})

df.head()
# Out:
# /var/folders/6p/rzcxcc9s58v5jv0m1clm5r180000gn/T/ipykernel_45005/1718764929.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Sex'] = df['Sex'].replace({'M': 0, 'F': 1, 'I': 2})
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    0   0.455     0.365   0.095        0.5140          0.2245
# 1    0   0.350     0.265   0.090        0.2255          0.0995
# 2    1   0.530     0.420   0.135        0.6770          0.2565
# 3    0   0.440     0.365   0.125        0.5160          0.2155
# 4    2   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight   Age
# 0          0.1010         0.150  16.5
# 1          0.0485         0.070   8.5
# 2          0.1415         0.210  10.5
# 3          0.1140         0.155  11.5
# 4          0.0395         0.055   8.5

# %%
df.shape
# Out:
# (3781, 9)

# %%
numerical_data.shape
# Out:
# (4177, 8)

# %%
plt.figure(figsize=(13, 9))

target='Age'

for i, col in enumerate(numerical_data):
  if(col != target):
    plt.subplot(3, 3, i+1)
    sns.scatterplot(df, x=col, y=target, hue=col)
    

plt.axis("off")
plt.tight_layout()

# %% [markdown]
# ### Define feature and Target

# %%
X = df.drop(columns=target) # Features
y = df[target] # Target value

X[:5], y[:5]
# Out:
# (   Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
#  0    0   0.455     0.365   0.095        0.5140          0.2245
#  1    0   0.350     0.265   0.090        0.2255          0.0995
#  2    1   0.530     0.420   0.135        0.6770          0.2565
#  3    0   0.440     0.365   0.125        0.5160          0.2155
#  4    2   0.330     0.255   0.080        0.2050          0.0895
#
#     Viscera weight  Shell weight
#  0          0.1010         0.150
#  1          0.0485         0.070
#  2          0.1415         0.210
#  3          0.1140         0.155
#  4          0.0395         0.055  ,
#  0    16.5
#  1     8.5
#  2    10.5
#  3    11.5
#  4     8.5
#  Name: Age, dtype: float64)

# %% [markdown]
# ### Feature Scaling

# %% [markdown]
# #### Standardization

# %%
std_scaler = StandardScaler()

# scaled_data
X_scaled = std_scaler.fit_transform(X)

columns_header = df.drop(columns=[target]).columns

X_scaled = pd.DataFrame(data=X_scaled, columns=columns_header)

X_scaled[:5]
# Out:
#         Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 0 -1.170205 -0.592283 -0.433414 -1.199002     -0.625502       -0.604416
# 1 -1.170205 -1.533969 -1.517342 -1.340646     -1.274339       -1.218729
# 2  0.031464  0.080351  0.162747 -0.065858     -0.258914       -0.447151
# 3 -1.170205 -0.726809 -0.433414 -0.349144     -0.621004       -0.648646
# 4  1.233132 -1.713338 -1.625735 -1.623932     -1.320443       -1.267874
#
#    Viscera weight  Shell weight
# 0       -0.719291     -0.619496
# 1       -1.237502     -1.270924
# 2       -0.319528     -0.130926
# 3       -0.590972     -0.578782
# 4       -1.326338     -1.393066

# %% [markdown]
# ### Splitting data

# %%
# Splitting data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, random_state=42, test_size=0.25)

X_train, y_train = X_train.astype('float32'), y_train.astype('float32')
X_test, y_test = X_test.astype('float32'), y_test.astype('float32')


len(X_train), len(X_test)
# Out:
# (2835, 946)

# %%
X_train[:5]
# Out:
#            Sex    Length  Diameter    Height  Whole weight  Shucked weight  \
# 905   1.233132 -1.220074 -1.246360 -1.623932     -1.222612       -1.108153
# 631   1.233132 -2.744709 -2.709664 -2.190504     -1.663416       -1.604518
# 1859 -1.170205  0.125193  0.162747 -0.349144     -0.121725        0.036928
# 3071  1.233132 -2.430814 -2.438682 -2.048861     -1.600444       -1.538172
# 3008  0.031464 -0.099018 -0.270824 -0.207501     -0.468072       -0.606873
#
#       Viscera weight  Shell weight
# 905        -1.227631     -1.311638
# 631        -1.553364     -1.718780
# 1859        0.154264     -0.379283
# 3071       -1.533622     -1.665851
# 3008       -0.378752     -0.334497

# %%
y_train[:5]
# Out:
# 1071     8.5
# 784      6.5
# 2064     9.5
# 3428     5.5
# 3351    14.5
# Name: Age, dtype: float32

# %% [markdown]
# ## Model Definition

# %% [markdown]
# #### Support Vector Regressor

# %% [markdown]
# #### Hyperparameters Tuning

# %%
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV

# Define the parameter distributions
param_distributions = {
    'C': [0.1, 1, 10, 100],
    'epsilon': [0.05, 0.1, 0.2, 0.3],
    'kernel': ['linear', 'rbf']
}

# Create a RandomizedSearchCV object
random_search = RandomizedSearchCV(
    SVR(),
    param_distributions,
    n_iter=10,
    cv=5,
    scoring='neg_mean_squared_error',
    random_state=42
)

# Fit the model
random_search.fit(X_train, y_train)

# Get the best parameters
best_params = random_search.best_params_

print(best_params)
kernel, epsilon, C = best_params['kernel'], best_params['epsilon'], best_params['C']
# Out:
# {'kernel': 'rbf', 'epsilon': 0.05, 'C': 10}

# %% [markdown]
# #### Defining the model

# %%
svr = SVR(kernel=kernel, C=C, epsilon=epsilon)

# %% [markdown]
# #### Fitting data

# %%
svr.fit(X_train, y_train)
# Out:
# SVR(C=10, epsilon=0.05)

# %% [markdown]
# #### Making predictions on train

# %%
y_pred = svr.predict(X_train)

# %% [markdown]
# #### Evaluating the model on train

# %%
r_squared_score = r2_score(y_train, y_pred)
mse_score = mean_squared_error(y_train, y_pred)
rmse_score = np.sqrt(mse_score)
mae_score = mean_absolute_error(y_train, y_pred)

print("R Squarred Error Score on Train: ", r_squared_score)
print("MSE Score on Train: ", mse_score)
print("RMSE Score on Train: ", rmse_score)
print("MAE Score on Train: ", mae_score)
# Out:
# R Squarred Error Score on Train:  0.572749066788389
# MSE Score on Train:  2.294342601321666
# RMSE Score on Train:  1.5147087513187696
# MAE Score on Train:  1.1112398348521977

# %% [markdown]
# #### Making predictions on test

# %%
y_pred_test = svr.predict(X_test)

# %% [markdown]
# #### Evaluating the model on test

# %%
r_squared_score = r2_score(y_test, y_pred_test)
mse_score = mean_squared_error(y_test, y_pred_test)
rmse_score = np.sqrt(mse_score)
mae_score = mean_absolute_error(y_test, y_pred_test)

print("R Squarred Error Score on Test: ", r_squared_score)
print("MSE Score on Test: ", mse_score)
print("RMSE Score on Test: ", rmse_score)
print("MAE Score on Test: ", mae_score)
# Out:
# R Squarred Error Score on Test:  0.5586768104990663
# MSE Score on Test:  2.4726443999469616
# RMSE Score on Test:  1.5724644351930386
# MAE Score on Test:  1.1963226144531078

# %% [markdown]
# #### Plot the train result

# %%
plot_pred(y_train, y_pred)

# %% [markdown]
# #### Plot the test result

# %%
plot_pred(y_test, y_pred_test)
